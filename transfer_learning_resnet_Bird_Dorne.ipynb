# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
from torch.utils.tensorboard import SummaryWriter
from sklearn import metrics
import matplotlib.pyplot as plt
import time
import os
import sys
import copy
import random

# %%
def init_random_seed(value=0):
    random.seed(value)
    np.random.seed(value)
    torch.manual_seed(value)
    torch.cuda.manual_seed(value)
    torch.backends.cudnn.deterministic = True

init_random_seed()

# %% [markdown]
# # Датасет

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224,224)),          ##256
        # transforms.RandomResizedCrop(224),   ##augmentation
        # transforms.RandomHorizontalFlip(),   ##augmentation
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize((224,224)),
        # transforms.CenterCrop(224),          ##augmentation
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = 'data'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
                  for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

# %% [markdown]
# # Девайс

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# # Визуализация датасета

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# # Обучение

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_epoch=0; best_acc = 0.0; best_loss = sys.maxsize
    hist_loss_train = []; hist_acc_train = []; 
    hist_loss_val = []; hist_acc_val = []
    
    step = 0 

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            if phase == 'train':
                hist_loss_train.append(epoch_loss)
                writer.add_scalar('Train loss', epoch_loss, global_step=epoch)
                hist_acc_train.append(epoch_acc)
                writer.add_scalar('Train Accuracy', epoch_acc, global_step=epoch)
                step += 1
            else:     
                hist_loss_val.append(epoch_loss)
                writer.add_scalar('Val loss', epoch_loss, global_step=epoch)
                hist_acc_val.append(epoch_acc)
                writer.add_scalar('Val Accuracy', epoch_acc, global_step=epoch)
                step += 1

            # deep copy the model
            if phase == 'val' and epoch_loss < best_loss:
                best_acc = epoch_acc
                best_loss = epoch_loss
                best_epoch = epoch
                best_model_wts = copy.deepcopy(model.state_dict())
    
        print()
        
        
    
    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# # Визуализация итогов

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            t0 = time.time()
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            print("Время инфренса батча(мс): {:4f}".format((time.time()-t0)*1000))
            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft = models.resnet18(pretrained=True)
for param in model_ft.parameters():
  param.requires_grad = False
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# Tensorboard
writer = SummaryWriter()
# Out:
# C:\Users\konto\anaconda3\envs\PythonGPU\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\konto\anaconda3\envs\PythonGPU\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs --host localhost
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 2008), started 0:13:29 ago. (Use '!kill 2008' to kill it.)
#       <iframe id="tensorboard-frame-629f6fbed82c07cd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-629f6fbed82c07cd");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import time
start_time = time.time()
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, 
                       num_epochs=100)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Epoch 0/99
# ----------
# train Loss: 0.2375 Acc: 0.9015
# val Loss: 0.4146 Acc: 0.8636
#
# Epoch 1/99
# ----------
# train Loss: 0.2315 Acc: 0.9031
# val Loss: 0.5102 Acc: 0.8182
#
# Epoch 2/99
# ----------
# train Loss: 0.2885 Acc: 0.8851
# val Loss: 0.5377 Acc: 0.8182
#
# Epoch 3/99
# ----------
# train Loss: 0.2623 Acc: 0.8933
# val Loss: 0.3926 Acc: 0.8727
#
# Epoch 4/99
# ----------
# train Loss: 0.2345 Acc: 0.8982
# val Loss: 0.3722 Acc: 0.8545
#
# Epoch 5/99
# ----------
# train Loss: 0.2272 Acc: 0.9130
# val Loss: 0.5209 Acc: 0.8455
#
# Epoch 6/99
# ----------
# train Loss: 0.2970 Acc: 0.8670
# val Loss: 0.4288 Acc: 0.8455
#
# Epoch 7/99
# ----------
# train Loss: 0.2612 Acc: 0.8818
# val Loss: 0.6246 Acc: 0.8000
#
# Epoch 8/99
# ----------
# train Loss: 0.2609 Acc: 0.8966
# val Loss: 0.4786 Acc: 0.8273
#
# Epoch 9/99
# ----------
# train Loss: 0.2243 Acc: 0.9064
# val Loss: 0.4104 Acc: 0.8636
#
# Epoch 10/99
# ----------
# train Loss: 0.2778 Acc: 0.8588
# val Loss: 0.4054 Acc: 0.8364
#
# Epoch 11/99
# ----------
# train Loss: 0.2599 Acc: 0.8933
# val Loss: 0.4250 Acc: 0.8182
#
# Epoch 12/99
# ----------
# train Loss: 0.2165 Acc: 0.9097
# val Loss: 0.4346 Acc: 0.8182
#
# Epoch 13/99
# ----------
# train Loss: 0.2833 Acc: 0.8785
# val Loss: 0.3902 Acc: 0.8455
#
# Epoch 14/99
# ----------
# train Loss: 0.2118 Acc: 0.9163
# val Loss: 0.4962 Acc: 0.8455
#
# Epoch 15/99
# ----------
# train Loss: 0.1756 Acc: 0.9228
# val Loss: 0.4676 Acc: 0.8273
#
# Epoch 16/99
# ----------
# train Loss: 0.2470 Acc: 0.8998
# val Loss: 0.6946 Acc: 0.7909
#
# Epoch 17/99
# ----------
# train Loss: 0.2334 Acc: 0.9097
# val Loss: 0.4387 Acc: 0.8182
#
# Epoch 18/99
# ----------
# train Loss: 0.2467 Acc: 0.8966
# val Loss: 0.5549 Acc: 0.8364
#
# Epoch 19/99
# ----------
# train Loss: 0.2129 Acc: 0.8998
# val Loss: 0.4002 Acc: 0.8364
#
# Epoch 20/99
# ----------
# train Loss: 0.2213 Acc: 0.9031
# val Loss: 0.4531 Acc: 0.8455
#
# Epoch 21/99
# ----------
# train Loss: 0.2625 Acc: 0.9031
# val Loss: 0.4164 Acc: 0.8364
#
# Epoch 22/99
# ----------
# train Loss: 0.2768 Acc: 0.8555
# val Loss: 0.4282 Acc: 0.8364
#
# Epoch 23/99
# ----------
# train Loss: 0.3430 Acc: 0.8506
# val Loss: 0.6033 Acc: 0.8273
#
# Epoch 24/99
# ----------
# train Loss: 0.2668 Acc: 0.8686
# val Loss: 0.7197 Acc: 0.7818
#
# Epoch 25/99
# ----------
# train Loss: 0.2624 Acc: 0.8883
# val Loss: 0.7594 Acc: 0.7818
#
# Epoch 26/99
# ----------
# train Loss: 0.2972 Acc: 0.8801
# val Loss: 0.5639 Acc: 0.8182
#
# Epoch 27/99
# ----------
# train Loss: 0.2867 Acc: 0.8752
# val Loss: 0.7259 Acc: 0.7909
#
# Epoch 28/99
# ----------
# train Loss: 0.2072 Acc: 0.9146
# val Loss: 0.4125 Acc: 0.8455
#
# Epoch 29/99
# ----------
# train Loss: 0.2184 Acc: 0.9097
# val Loss: 0.3358 Acc: 0.8818
#
# Epoch 30/99
# ----------
# train Loss: 0.2279 Acc: 0.9048
# val Loss: 0.3676 Acc: 0.8273
#
# Epoch 31/99
# ----------
# train Loss: 0.1830 Acc: 0.9278
# val Loss: 0.4542 Acc: 0.8000
#
# Epoch 32/99
# ----------
# train Loss: 0.2310 Acc: 0.9015
# val Loss: 0.4973 Acc: 0.8273
#
# Epoch 33/99
# ----------
# train Loss: 0.2764 Acc: 0.8785
# val Loss: 0.3925 Acc: 0.8455
#
# Epoch 34/99
# ----------
# train Loss: 0.2985 Acc: 0.8834
# val Loss: 0.5157 Acc: 0.7909
#
# Epoch 35/99
# ----------
# train Loss: 0.2491 Acc: 0.8982
# val Loss: 0.3720 Acc: 0.8455
#
# Epoch 36/99
# ----------
# train Loss: 0.2359 Acc: 0.8949
# val Loss: 0.6045 Acc: 0.8091
#
# Epoch 37/99
# ----------
# train Loss: 0.2511 Acc: 0.8982
# val Loss: 0.4228 Acc: 0.8364
#
# Epoch 38/99
# ----------
# train Loss: 0.2540 Acc: 0.8966
# val Loss: 0.4401 Acc: 0.8545
#
# Epoch 39/99
# ----------
# train Loss: 0.2795 Acc: 0.8933
# val Loss: 0.4375 Acc: 0.8273
#
# Epoch 40/99
# ----------
# train Loss: 0.2350 Acc: 0.8998
# val Loss: 0.4461 Acc: 0.8545
#
# Epoch 41/99
# ----------
# train Loss: 0.2273 Acc: 0.9080
# val Loss: 0.4265 Acc: 0.8364
#
# Epoch 42/99
# ----------
# train Loss: 0.2306 Acc: 0.8933
# val Loss: 0.5499 Acc: 0.8182
#
# Epoch 43/99
# ----------
# train Loss: 0.2174 Acc: 0.9146
# val Loss: 0.4174 Acc: 0.8545
#
# Epoch 44/99
# ----------
# train Loss: 0.2750 Acc: 0.8834
# val Loss: 0.4106 Acc: 0.8273
#
# Epoch 45/99
# ----------
# train Loss: 0.2660 Acc: 0.8801
# val Loss: 0.4496 Acc: 0.8273
#
# Epoch 46/99
# ----------
# train Loss: 0.2141 Acc: 0.8949
# val Loss: 0.7245 Acc: 0.7909
#
# Epoch 47/99
# ----------
# train Loss: 0.2681 Acc: 0.8736
# val Loss: 0.6523 Acc: 0.7818
#
# Epoch 48/99
# ----------
# train Loss: 0.2369 Acc: 0.9048
# val Loss: 0.4204 Acc: 0.8182
#
# Epoch 49/99
# ----------
# train Loss: 0.2781 Acc: 0.8900
# val Loss: 0.6016 Acc: 0.8182
#
# Epoch 50/99
# ----------
# train Loss: 0.2392 Acc: 0.8998
# val Loss: 0.4093 Acc: 0.8545
#
# Epoch 51/99
# ----------
# train Loss: 0.1930 Acc: 0.9212
# val Loss: 0.4968 Acc: 0.8182
#
# Epoch 52/99
# ----------
# train Loss: 0.2690 Acc: 0.8801
# val Loss: 0.3858 Acc: 0.8364
#
# Epoch 53/99
# ----------
# train Loss: 0.2646 Acc: 0.8933
# val Loss: 0.4093 Acc: 0.8455
#
# Epoch 54/99
# ----------
# train Loss: 0.3010 Acc: 0.8752
# val Loss: 0.5034 Acc: 0.8091
#
# Epoch 55/99
# ----------
# train Loss: 0.2303 Acc: 0.8966
# val Loss: 0.6360 Acc: 0.8000
#
# Epoch 56/99
# ----------
# train Loss: 0.2749 Acc: 0.8933
# val Loss: 0.8888 Acc: 0.7455
#
# Epoch 57/99
# ----------
# train Loss: 0.2553 Acc: 0.8966
# val Loss: 0.4556 Acc: 0.8455
#
# Epoch 58/99
# ----------
# train Loss: 0.2249 Acc: 0.9179
# val Loss: 0.4888 Acc: 0.8273
#
# Epoch 59/99
# ----------
# train Loss: 0.2634 Acc: 0.8982
# val Loss: 0.3948 Acc: 0.8455
#
# Epoch 60/99
# ----------
# train Loss: 0.2039 Acc: 0.9113
# val Loss: 0.4208 Acc: 0.8364
#
# Epoch 61/99
# ----------
# train Loss: 0.2374 Acc: 0.9031
# val Loss: 0.4537 Acc: 0.8273
#
# Epoch 62/99
# ----------
# train Loss: 0.2224 Acc: 0.8966
# val Loss: 0.4483 Acc: 0.8273
#
# Epoch 63/99
# ----------
# train Loss: 0.2688 Acc: 0.8933
# val Loss: 0.5145 Acc: 0.8182
#
# Epoch 64/99
# ----------
# train Loss: 0.2189 Acc: 0.9097
# val Loss: 0.3734 Acc: 0.8364
#
# Epoch 65/99
# ----------
# train Loss: 0.2454 Acc: 0.9015
# val Loss: 0.6897 Acc: 0.8091
#
# Epoch 66/99
# ----------
# train Loss: 0.2155 Acc: 0.9113
# val Loss: 0.3900 Acc: 0.8455
#
# Epoch 67/99
# ----------
# train Loss: 0.2241 Acc: 0.8966
# val Loss: 0.4054 Acc: 0.8636
#
# Epoch 68/99
# ----------
# train Loss: 0.2604 Acc: 0.8818
# val Loss: 0.3439 Acc: 0.8636
#
# Epoch 69/99
# ----------
# train Loss: 0.2497 Acc: 0.8933
# val Loss: 0.5498 Acc: 0.8182
#
# Epoch 70/99
# ----------
# train Loss: 0.2201 Acc: 0.9015
# val Loss: 0.4954 Acc: 0.8364
#
# Epoch 71/99
# ----------
# train Loss: 0.2905 Acc: 0.8670
# val Loss: 0.5311 Acc: 0.8364
#
# Epoch 72/99
# ----------
# train Loss: 0.2627 Acc: 0.8867
# val Loss: 0.6022 Acc: 0.8182
#
# Epoch 73/99
# ----------
# train Loss: 0.2140 Acc: 0.9146
# val Loss: 0.4999 Acc: 0.8273
#
# Epoch 74/99
# ----------
# train Loss: 0.2760 Acc: 0.8834
# val Loss: 0.5480 Acc: 0.8182
#
# Epoch 75/99
# ----------
# train Loss: 0.2455 Acc: 0.9048
# val Loss: 0.4030 Acc: 0.8455
#
# Epoch 76/99
# ----------
# train Loss: 0.2716 Acc: 0.8752
# val Loss: 0.4383 Acc: 0.8455
#
# Epoch 77/99
# ----------
# train Loss: 0.2511 Acc: 0.8949
# val Loss: 0.4840 Acc: 0.8182
#
# Epoch 78/99
# ----------
# train Loss: 0.2638 Acc: 0.8834
# val Loss: 0.4530 Acc: 0.8364
#
# Epoch 79/99
# ----------
# train Loss: 0.2456 Acc: 0.8900
# val Loss: 0.3920 Acc: 0.8727
#
# Epoch 80/99
# ----------
# train Loss: 0.2418 Acc: 0.8916
# val Loss: 0.6519 Acc: 0.8000
#
# Epoch 81/99
# ----------
# train Loss: 0.2687 Acc: 0.8883
# val Loss: 0.3564 Acc: 0.8727
#
# Epoch 82/99
# ----------
# train Loss: 0.2227 Acc: 0.9080
# val Loss: 0.3970 Acc: 0.8545
#
# Epoch 83/99
# ----------
# train Loss: 0.2598 Acc: 0.8867
# val Loss: 0.4076 Acc: 0.8545
#
# Epoch 84/99
# ----------
# train Loss: 0.2450 Acc: 0.9097
# val Loss: 0.6076 Acc: 0.8091
#
# Epoch 85/99
# ----------
# train Loss: 0.2114 Acc: 0.9097
# val Loss: 0.6265 Acc: 0.8182
#
# Epoch 86/99
# ----------
# train Loss: 0.2567 Acc: 0.8719
# val Loss: 0.4019 Acc: 0.8545
#
# Epoch 87/99
# ----------
# train Loss: 0.2398 Acc: 0.8949
# val Loss: 0.6104 Acc: 0.8182
#
# Epoch 88/99
# ----------
# train Loss: 0.2833 Acc: 0.8703
# val Loss: 0.3487 Acc: 0.8545
#
# Epoch 89/99
# ----------
# train Loss: 0.2541 Acc: 0.8916
# val Loss: 0.4232 Acc: 0.8364
#
# Epoch 90/99
# ----------
# train Loss: 0.2619 Acc: 0.8867
# val Loss: 0.5198 Acc: 0.8364
#
# Epoch 91/99
# ----------
# train Loss: 0.2159 Acc: 0.8998
# val Loss: 0.4464 Acc: 0.8364
#
# Epoch 92/99
# ----------
# train Loss: 0.2568 Acc: 0.8998
# val Loss: 0.5186 Acc: 0.8273
#
# Epoch 93/99
# ----------
# train Loss: 0.2768 Acc: 0.8933
# val Loss: 0.4985 Acc: 0.8455
#
# Epoch 94/99
# ----------
# train Loss: 0.2399 Acc: 0.9064
# val Loss: 0.5238 Acc: 0.8273
#
# Epoch 95/99
# ----------
# train Loss: 0.2271 Acc: 0.9130
# val Loss: 0.6033 Acc: 0.7909
#
# Epoch 96/99
# ----------
# train Loss: 0.2066 Acc: 0.9113
# val Loss: 0.4799 Acc: 0.8182
#
# Epoch 97/99
# ----------
# train Loss: 0.2750 Acc: 0.8966
# val Loss: 0.6205 Acc: 0.8091
#
# Epoch 98/99
# ----------
# train Loss: 0.2532 Acc: 0.9031
# val Loss: 0.3917 Acc: 0.8273
#
# Epoch 99/99
# ----------
# train Loss: 0.2981 Acc: 0.8801
# val Loss: 0.8062 Acc: 0.7545
#
# --- 1267.3191223144531 seconds ---

# %%
visualize_model(model_ft.to(device),num_images=4)
# Out:
# Время инфренса батча(мс): 4.998207

# %% [markdown]
# # Confusion matrix

# %%
true_labels=[]
pred_labels=[]
for inputs, labels in dataloaders['val']:
  pred = model_ft.forward(inputs.to(device))
  _, pred = torch.max(pred, 1)
  labels.to(torch.device("cpu"))
  pred.to(torch.device("cpu"))
  true_labels.extend(labels.tolist());
  pred_labels.extend(pred.tolist());
cm=metrics.confusion_matrix(true_labels,pred_labels)
print(cm)
from pandas import DataFrame
import seaborn as sn
df_cm = DataFrame(cm, index=class_names, columns=class_names)
ax = sn.heatmap(df_cm, cmap='Oranges', annot=True)
# Out:
# [[43  7]
#  [ 6 54]]

# %%
from torchsummary import summary
summary(model_ft, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#        BasicBlock-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
#              ReLU-14           [-1, 64, 56, 56]               0
#            Conv2d-15           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-16           [-1, 64, 56, 56]             128
#              ReLU-17           [-1, 64, 56, 56]               0
#        BasicBlock-18           [-1, 64, 56, 56]               0
#            Conv2d-19          [-1, 128, 28, 28]          73,728
#       BatchNorm2d-20          [-1, 128, 28, 28]             256
#              ReLU-21          [-1, 128, 28, 28]               0
#            Conv2d-22          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-23          [-1, 128, 28, 28]             256
#            Conv2d-24          [-1, 128, 28, 28]           8,192
#       BatchNorm2d-25          [-1, 128, 28, 28]             256
#              ReLU-26          [-1, 128, 28, 28]               0
#        BasicBlock-27          [-1, 128, 28, 28]               0
#            Conv2d-28          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-29          [-1, 128, 28, 28]             256
#              ReLU-30          [-1, 128, 28, 28]               0
#            Conv2d-31          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-32          [-1, 128, 28, 28]             256
#              ReLU-33          [-1, 128, 28, 28]               0
#        BasicBlock-34          [-1, 128, 28, 28]               0
#            Conv2d-35          [-1, 256, 14, 14]         294,912
#       BatchNorm2d-36          [-1, 256, 14, 14]             512
#              ReLU-37          [-1, 256, 14, 14]               0
#            Conv2d-38          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-39          [-1, 256, 14, 14]             512
#            Conv2d-40          [-1, 256, 14, 14]          32,768
#       BatchNorm2d-41          [-1, 256, 14, 14]             512
#              ReLU-42          [-1, 256, 14, 14]               0
#        BasicBlock-43          [-1, 256, 14, 14]               0
#            Conv2d-44          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-45          [-1, 256, 14, 14]             512
#              ReLU-46          [-1, 256, 14, 14]               0
#            Conv2d-47          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-48          [-1, 256, 14, 14]             512
#              ReLU-49          [-1, 256, 14, 14]               0
#        BasicBlock-50          [-1, 256, 14, 14]               0
#            Conv2d-51            [-1, 512, 7, 7]       1,179,648
#       BatchNorm2d-52            [-1, 512, 7, 7]           1,024
#              ReLU-53            [-1, 512, 7, 7]               0
#            Conv2d-54            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-55            [-1, 512, 7, 7]           1,024
#            Conv2d-56            [-1, 512, 7, 7]         131,072
#       BatchNorm2d-57            [-1, 512, 7, 7]           1,024
#              ReLU-58            [-1, 512, 7, 7]               0
#        BasicBlock-59            [-1, 512, 7, 7]               0
#            Conv2d-60            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-61            [-1, 512, 7, 7]           1,024
#              ReLU-62            [-1, 512, 7, 7]               0
#            Conv2d-63            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-64            [-1, 512, 7, 7]           1,024
#              ReLU-65            [-1, 512, 7, 7]               0
#        BasicBlock-66            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                    [-1, 2]           1,026
# ================================================================
# Total params: 11,177,538
# Trainable params: 1,026
# Non-trainable params: 11,176,512
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 62.79
# Params size (MB): 42.64
# Estimated Total Size (MB): 106.00
# ----------------------------------------------------------------

# %%
model_ft.eval()
model_ft=model_ft.to(torch.device("cpu"))

input_tensor = torch.rand(1,3,224,224)
script_model = torch.jit.trace(model_ft,input_tensor)
script_model.save("resnetBD.pt")
